# %% [markdown]
# <a href="https://colab.research.google.com/github/KalyanMohanty/projects/blob/main/download_dataset_from_kaggle.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install -q kaggle

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-0ce5e59c-89a6-4669-a710-b79319be6adf" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0ce5e59c-89a6-4669-a710-b79319be6adf">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# {'kaggle.json': b'{"username":"kalyanmohanty","key":"81f8b160f1efd9dc44c5bff72bb7bc60"}'}

# %%
 ! mkdir ~/.kaggle

# %%
! cp kaggle.json ~/.kaggle/

# %%
 ! chmod 600 ~/.kaggle/kaggle.json

# %%
! kaggle datasets list
# Out:
# ref                                                            title                                             size  lastUpdated          downloadCount  voteCount  usabilityRating
# -------------------------------------------------------------  -----------------------------------------------  -----  -------------------  -------------  ---------  ---------------
# datasets/piterfm/2022-ukraine-russian-war                      2022 Ukraine Russia War                            2KB  2022-04-14 11:06:51           7909        445  1.0
# datasets/kamilpytlak/personal-key-indicators-of-heart-disease  Personal Key Indicators of Heart Disease           3MB  2022-02-16 10:18:03          12979        281  1.0
# datasets/ankanhore545/cost-of-living-index-2022                Cost of Living Index 2022                          4KB  2022-04-09 06:22:10           2609         48  0.8235294
# ...

# %%
! kaggle datasets download -d lemontyc/sweet-pepper
# Out:
# ...
#  99% 1.11G/1.12G [00:40<00:00, 36.7MB/s]
# 100% 1.12G/1.12G [00:40<00:00, 29.9MB/s]

# %%
! mkdir sweet-paper

# %%
! unzip sweet-pepper.zip -d train
# Out:
# Archive:  sweet-pepper.zip
#   inflating: train/dataset_620_red_yellow_cart_only/620_images_via_project.json
#   inflating: train/dataset_620_red_yellow_cart_only/_Color_1607625615060.01098632812500.png
#   inflating: train/dataset_620_red_yellow_cart_only/_Color_1607625616325.71459960937500.png
#   inflating: train/dataset_620_red_yellow_cart_only/_Color_1607625617591.46923828125000.png
#   inflating: train/dataset_620_red_yellow_cart_only/_Color_1607625618857.04956054687500.png
#   inflating: train/dataset_620_red_yellow_cart_only/_Color_1607625620122.67236328125000.png
#   inflating: train/dataset_620_red_yellow_cart_only/_Color_1607625621388.33471679687500.png
#   inflating: train/dataset_620_red_yellow_cart_only/_Color_1607625622653.98632812500000.png
#   inflating: train/dataset_620_red_yellow_cart_only/_Color_1607625623919.66210937500000.png
#   inflating: train/dataset_620_red_yellow_cart_only/_Color_1607625625193.59399414062500.png
# ...

# %%
import os
from tensorflow.keras.preprocessing import image
images = []
path = os.listdir('/content/train/')
path
# Out:
# ['dataset_620_red_yellow_cart_only']

# %%
# for folder in path:
#   files = os.listdir("/content/train/"+folder)
#   for file in files:
#     img = image.load_img("/content/train/"+folder+"/"+file,target_size=(200,200))
#     images.append(img)
# Out:
# ---------------------------------------------------------------------------
# UnidentifiedImageError                    Traceback (most recent call last)
# <ipython-input-20-fd8b12e8c2a5> in <module>()
#       2   files = os.listdir("/content/train/"+folder)
#       3   for file in files:
# ----> 4     img = image.load_img("/content/train/"+folder+"/"+file,target_size=(200,200))
#       5     images.append(img)
#
# /usr/local/lib/python3.7/dist-packages/keras/preprocessing/image.py in load_img(path, grayscale, color_mode, target_size, interpolation)
#     312   """
#     313   return image.load_img(path, grayscale=grayscale, color_mode=color_mode,
# --> 314                         target_size=target_size, interpolation=interpolation)
#     315
#     316
#
# /usr/local/lib/python3.7/dist-packages/keras_preprocessing/image/utils.py in load_img(path, grayscale, color_mode, target_size, interpolation)
#     112                           'The use of `load_img` requires PIL.')
# ...
