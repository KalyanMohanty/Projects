# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install h5py

# %%
import os
os.getcwd()
# Out:
# '/content'

# %%
os.chdir('/content/drive/MyDrive/Colab Notebooks/Fruit Classification Notebook/cnn_tuning')
os.getcwd()
# Out:
# '/content/drive/MyDrive/Colab Notebooks/Fruit Classification Notebook/cnn_tuning'

# %%
# !ls
# Out:
# CNN_Accuracy_14_epoch.png  cnn_tunned_model.png
# CNN_Loss_15_epoch.png	   confusion_matrix_14_epochs.png
# cnn_tunned_final_model.h5

# %%
import tensorflow as tf
converter = tf.lite.TFLiteConverter.from_saved_model( 'cnn_tunned_final_model.h5' ) # Your model's name
model = converter.convert()
file = open( 'model.tflite' , 'wb' ) 
file.write( model )
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-12-7d86ca30141b> in <module>()
#       1 import tensorflow as tf
# ----> 2 converter = tf.lite.TFLiteConverter.from_saved_model( 'cnn_tunned_final_model.h5' ) # Your model's name
#       3 model = converter.convert()
#       4 file = open( 'model.tflite' , 'wb' )
#       5 file.write( model )
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/lite/python/lite.py in from_saved_model(cls, saved_model_dir, signature_keys, tags)
#    1646
#    1647     with context.eager_mode():
# -> 1648       saved_model = _load(saved_model_dir, tags)
#    1649     if not signature_keys:
#    1650       signature_keys = saved_model.signatures
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/saved_model/load.py in load(export_dir, tags, options)
# ...

# %%
from tensorflow.keras.models import load_model
model2 = load_model('cnn_tunned_final_model.h5')
model2.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_12 (Conv2D)          (None, 198, 198, 64)      1792
#
#  conv2d_13 (Conv2D)          (None, 196, 196, 64)      36928
#
#  max_pooling2d_6 (MaxPooling  (None, 98, 98, 64)       0
#  2D)
#
#  dropout_8 (Dropout)         (None, 98, 98, 64)        0
#
#  conv2d_14 (Conv2D)          (None, 96, 96, 128)       73856
#
#  conv2d_15 (Conv2D)          (None, 94, 94, 128)       147584
#
#  max_pooling2d_7 (MaxPooling  (None, 47, 47, 128)      0
#  2D)
#
#  dropout_9 (Dropout)         (None, 47, 47, 128)       0
#
#  conv2d_16 (Conv2D)          (None, 45, 45, 256)       295168
#
#  conv2d_17 (Conv2D)          (None, 43, 43, 256)       590080
#
#  max_pooling2d_8 (MaxPooling  (None, 21, 21, 256)      0
#  2D)
#
#  dropout_10 (Dropout)        (None, 21, 21, 256)       0
#
#  flatten_2 (Flatten)         (None, 112896)            0
#
# ...
